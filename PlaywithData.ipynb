# %% [markdown]
# **Assignment #0 - Data and Visualization**
#
# Name : **Siddhi Degaonkar**
#
# **1. INTRODUCTION**

# %% [markdown]
# **Purpose and Objective**:
# Assignment # 0 is implemented in order to get familiar with Python, matplotlib, pandas, numpy, Jupyter Notebook.
# Also to get hold of handling the dataset before working on the Machine Learning Algorithms.
#
# **Scope of Assignment**
# Assignment # 0 consist of introduction to Python, numpy, matplotlib, pandas, and Jupyter notebook.
# In this assignment I am searching datasets and performing data visualization for Regression and Classification.
# For each of the dataset following tasks are performed:
# 1. Introduce data and data source
# 2. Read and analyze the raw data from csv file.
# 3. Data preprocessing activities like:
#    checking and filling up missing values, reducing noisy data, removing inconsistent data.
# 4. Data Visualization:
#    Data Visualization is used to represent the data in graphical or pictorial manner. It makes the data more
#    interpretable.
# 5. Extracting observations from visualized data.

# %% [markdown]
# **Conclusion** is derived and **references** are presented.

# %% [markdown]
# **Index of the Assignment**
# 1. INTRODUCTION
# 2. LINEAR ALGEBRA
# 3. PROBABILITY
# 4. INTRODUCTION TO DATA FOR REGRESSION AND SOURCE
# 5. READING OF REGRESSION DATA
# 6. PREPROCESSING OF REGRESSION DATA
# 7. DATA VISUALIZATION FOR REGRESSION DATASET
# 8. PRELIMINARY OBSERVATION FOR REGRESSION DATASET
# 9. INTRODUCTION TO DATA FOR CLASSIFICATION AND SOURCE
# 10. READING OF CLASSIFICATION DATA
# 11. PREPROCESSING OF CLASSIFICATION DATA
# 12. DATA VISUALIZATION FOR CLASSIFICATION DATASET
# 13. PRELIMINARY OBSERVATION FOR CLASSIFICATION DATASET
# 14. CONCLUSION
# 15. REFERENCES

# %% [markdown]
# **2. LINEAR ALGEBRA**

# %% [markdown]
# Linear algebra is the branch of mathematics concerning linear equations such as, linear functions and their representations through matrices and vectors. Linear Algebra has a tight relationship with Machine Learning.
# A good understanding of linear algebra is essential for understanding and working with many machine learning algorithms, especially deep learning algorithm.

# %% [markdown]
# Linear Algebra starts with the point, Vectors, Scalers, Matrices, Tensors.
#
# 1. Scaler: Scaler is a single number. It only has magnitude. Real numbers are scaler.
#            Scalers are represented using lower case.
#            * For example : x = 3, 4
#                          x belongs to Real, Natural Number
#
# 2. Vectors: Vector is an array of numbers.  This array of numbers is a way of identifying that point in space, where             each number represents the vector’s  component that dimension.
#             It has magnitude as well as direction.
#             * For example : Velocity Aeroplane's velocity is 250 mph north-by-northeast.
#
# Vector a = [1, 2]. Graphically,this vector as an arrow in the x-y plane, pointing from the origin to the point at x=1, y=2
# Given below is an image of vector.

# %%
from IPython.display import Image
Image(filename='output1.png', width = '100')

# %% [markdown]
# To calculate the magnitude of vector we use Pythagorean theorem (z^2 = x^2 + y^2)

# %% [markdown]
# 3. Matrices: Matrix is a 2 - D rectangular array of numbers. A major application of matrices is to represent linear                transformations, that is, generalizations of linear functions. Various matrix operations include :
#              * Matrix Addition.
#              * Matrix Multiplication.
#              * Matrix Transpose.
#              * Matrix Subtraction.

# %% [markdown]
# 4. Tensors: Tensor is an array of numbers arranged on a regular grid with a variable number of dimensions. Tensor can             have zero dimensions and can be treated as a scaler. Tensor can take several different forms such as                 tangent vector at a point, matrices. It can also have higher dimensionality.

# %% [markdown]
# 5. Norm: We use norm to measure the size of vector.

# %% [markdown]
# 6. Trace Operator: It gives the sum of all the diagonal elements.

# %% [markdown]
# 7. Span: Is of a set of vectors is the set of all points obtainable by linear combination of the original vectors.

# %% [markdown]
# **3. PROBABILITY**

# %% [markdown]
# Probability is a mathematical framework for quantifying our uncertainty about the world. It allows us to reason effectively in situations where being certain is impossible. Probability theory is at the foundation of many machine learning algorithms.
# Probability in simple words is likelihood or chance of an event occurring. Probability = the number of ways of achieving success.

# %% [markdown]
# Notations :
# 1. X is the Random variable
# 2. P(X) represents the probability of X.
# 3. Sample Space : Contains all the possible outcomes.

# %% [markdown]
# * Marginal Probability : The probability distribution over a subset is called as Marginal Probability.
# * Conditional Probability : The probability of event X will occur when event Y has already occurred is known as     conditional probability.
#       p(x/y) = p(y/x).p(x)/p(y)

# %% [markdown]
# * Any joint probability distribution over many random variables may be decomposed into conditional distributions over only one variable:
# * **P(x(1),...,x(n))=P(x(1))Πni=2P(x(i) |x(1),...,x(i−1)).** This observation is known as the **chain rule** or product rule of probability.
# * It follows immediately from the definition of conditional probability in equation.

# %% [markdown]
# **4. INTRODUCTION TO DATA FOR REGRESSION AND SOURCE**

# %% [markdown]
# **About data**

# %% [markdown]
# Dataset includes 40,838 results of international football matches starting from the very first official match in 1972 up to 2019. The matches range from FIFA World Cup to FIFI Wild Cup to regular friendly matches.
#
# **'results.csv'** includes the following columns:
#
# * date - date of the match
# * home_team - the name of the home team
# * away_team - the name of the away team
# * home_score - full-time home team score including extra time, not including penalty-shootouts
# * away_score - full-time away team score including extra time, not including penalty-shootouts
# * tournament - the name of the tournament
# * city - the name of the city/town/administrative unit where the match was played
# * country - the name of the country where the match was played
# * neutral - TRUE/FALSE column indicating whether the match was played at a neutral venue

# %% [markdown]
# **Source**
# * This dataset is obtained from Kaggle.
# * The data is gathered from several sources including but not limited to Wikipedia, fifa.com, rsssf.com and individual football associations' websites.

# %% [markdown]
# **5. READING THE REGRESSION DATA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
match_df = pd.read_csv('results.csv')
match_df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
print(match_df.shape)
# Out:
# (40839, 9)

# %% [markdown]
# **6. PREPROCESSING OF REGRESSION DATA**

# %%
print("MATCH dataset consists of total {rows} rows.".format(rows = len(match_df)))
# Out:
# MATCH dataset consists of total 40839 rows.

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40839 entries, 0 to 40838
# Data columns (total 9 columns):
# date          40839 non-null object
# home_team     40839 non-null object
# away_team     40839 non-null object
# home_score    40839 non-null int64
# away_score    40839 non-null int64
# tournament    40839 non-null object
# city          40839 non-null object
# country       40839 non-null object
# neutral       40839 non-null bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.5+ MB

# %%
#Calculate percentage of missing values for each column
missing_values = match_df.isnull().mean()
missing_values.sum()
# Out:
# 0.0

# %% [markdown]
# * Dataset has **NO** missing values.

# %% [markdown]
# **7.DATA VISUALIZATION FOR REGRESSION DATASET**

# %%
match_df.describe()
# Out:
#          home_score    away_score
# count  40839.000000  40839.000000
# mean       1.745709      1.188105
# std        1.749145      1.405120
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
match_df.nunique()
# Out:
# date          15115
# home_team       309
# away_team       306
# home_score       26
# away_score       22
# tournament      109
# city           1960
# country         266
# neutral           2
# dtype: int64

# %%
match_df.nunique().sum()
# Out:
# 18115

# %%
sns.pairplot(match_df, hue = 'neutral')
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# //anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
match_df['tournament'].value_counts()
# Out:
# Friendly                                16911
# FIFA World Cup qualification             7100
# UEFA Euro qualification                  2432
# African Cup of Nations qualification     1616
# FIFA World Cup                            900
# Copa América                              813
# AFC Asian Cup qualification               724
# African Cup of Nations                    690
# CECAFA Cup                                620
# CFU Caribbean Cup qualification           606
# Merdeka Tournament                        503
# British Championship                      501
# AFC Asian Cup                             370
# Island Games                              350
# Gulf Cup                                  333
# Gold Cup                                  327
# AFF Championship                          293
# COSAFA Cup                                292
# UEFA Euro                                 286
# Nordic Championship                       283
# ...

# %%
venues = pd.DataFrame(match_df['country'].value_counts())
venues
# Out:
#                           country
# United States                1144
# France                        801
# England                       687
# Malaysia                      644
# Sweden                        637
# Germany                       581
# Brazil                        529
# Spain                         517
# Thailand                      483
# Italy                         480
# Switzerland                   477
# Austria                       475
# United Arab Emirates          472
# South Africa                  470
# Qatar                         467
# South Korea                   453
# Argentina                     449
# Hungary                       431
# Chile                         405
# Belgium                       396
# Mexico                        392
# Egypt                         391
# Netherlands                   390
# Norway                        385
# Scotland                      385
# Uruguay                       374
# ...

# %%
sns.barplot(x=match_df['tournament'].value_counts().index[:15],y=match_df['tournament'].value_counts().values[:15])
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x="home_score", y="away_score", hue="neutral",data=match_df)
plt.show()

# %%
majority = match_df[match_df['tournament'].isin(['Copa América','FIFA World Cup','UEFA Euro'])]
majority.sample(5)
colors=('lightgreen','skyblue')
plt.pie(majority['neutral'].value_counts(), labels=['Tie','Not a Tie'], colors=colors,
       startangle=80, explode=(0.1,0), autopct='%1.2f%%', shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a21b5d828>,
# ...
#  [Text(-0.9474289904180152, -0.7364633786655661, 'Tie'),
#   Text(0.8684765113432215, 0.6750915117560784, 'Not a Tie')],
#  [Text(-0.5526669110771755, -0.4296036375549135, '76.59%'),
#   Text(0.4737144607326662, 0.3682317336851337, '23.41%')])

# %% [markdown]
# **8. PRELIMINARY OBSERVATION FOR REGRESSION DATA**

# %% [markdown]
# * The mean home_score of a team is 1.74, away_score=1.18.
# * The maximum home_score is 31, away_score= 21
# * Dataset has total 18115 unique values.
# * The count of Friendly Tournamet is highest among all.
# * More than 75 % of the total Majority of the world tournaments end up in a TIE.
# * Highest number of Matches were played in USA and lowest in Lautoka.

# %% [markdown]
# **9. INTRODUCTION TO DATA FOR CLASSIFICATION AND SOURCE**

# %% [markdown]
# **About Data**
#
# This is a  Portuguese bank dataset in the UCI Machine Learning Repository. The dataset gives you information about a marketing campaign of a financial institution in which we will have to analyze in order to find ways to look for future strategies in order to improve future marketing campaigns for the bank.
#
# **Data Set Information:**
#
# The data is related with direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed.
#
# The goal of this classification is to predict whether the client will subscribe to the term deposit or not.
#
# It consists of following columns:
# age,
# job,
# marital,
# education,
# default,
# balance,
# housing,
# loan,
# contact,
# day,
# month,
# duration,
# campaign,
# pdays,
# previous,
# poutcome,
# deposit (Target Attribute)
#
# **Source**
#
# [Moro et al., 2014] S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, Elsevier, 62:22-31, June 2014

# %% [markdown]
# **10. READING THE CLASSIFICATION DATA**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('bank.csv')
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
print(df.shape)
# Out:
# (11162, 17)

# %% [markdown]
# **11. PREPROCESSING OF CLASSIFICATION DATA**

# %% [markdown]
# Check whether the data has any missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
# age          11162 non-null int64
# job          11162 non-null object
# marital      11162 non-null object
# education    11162 non-null object
# default      11162 non-null object
# balance      11162 non-null int64
# housing      11162 non-null object
# loan         11162 non-null object
# contact      11162 non-null object
# day          11162 non-null int64
# month        11162 non-null object
# duration     11162 non-null int64
# campaign     11162 non-null int64
# pdays        11162 non-null int64
# previous     11162 non-null int64
# poutcome     11162 non-null object
# deposit      11162 non-null object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
print("Bank marketing dataset consists of {rows} rows.".format(rows = len(df)))
# Out:
# Bank marketing dataset consists of 11162 rows.

# %%
#find percentage of missing values for each column
missing_values = df.isnull().mean()
missing_values.sum()
# Out:
# 0.0

# %% [markdown]
# * Bank Marketing Dataset has **NO** missing values.

# %% [markdown]
# **12. DATA VISUALIZATION FOR CLASSIFICATION DATASET**

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
sns.pairplot(df)

# %%
c = df.corr()
c
sns.heatmap(c)

# %%
# Classification according to Jobs
plt.figure(figsize=[15,5])
sns.countplot(x='job', hue='deposit', data=df)

# %%
# Classification based on housing and loan status
plt.figure(figsize=[15,5])
plt.subplot(1,3,1)
sns.countplot(x='housing', hue='deposit', data=df)
plt.subplot(1,3,2)
sns.countplot(x='loan', hue='deposit', data=df)
plt.subplot(1,3,3)
sns.countplot(x='marital', hue='deposit', data=df)
plt.show()

# %%
# Classification based on Month
sns.countplot(x='month', hue='deposit', data=df)

# %%
# Classification based on Education
sns.countplot(x='education', hue='deposit', data=df)

# %%
plt.figure(figsize=[15,10])
sns.countplot(x='age', hue='deposit', data=df)

# %%
value_count = df['deposit'].value_counts()
value_count.plot.bar(title = 'Deposits counts')

# %%
# Based on days of Campaign: number of contacts performed during this campaign.
sns.countplot(x='campaign', hue='deposit', data=df)

# %% [markdown]
# **13. PRELIMINARY OBSERVATION FOR CLASSIFICATION DATA**

# %% [markdown]
# * Mean Age = 41 yrs (minimum_age = 18 , maximum_age = 95)
# * The mean balance is 1,528.
# * The mean pdays = 51.33
# * The Campaigning was done minimum for 1 day and maximum for 63 days.
# * Mean Call duration was 371.99 seconds.
# * Married people said more yes for Opening Term Subscription, deposit as compared to Divorces and Singles.
# * In Education people who are Secondary Level Educated tend to say yes for the Deposit compared to other.
# * The Cellular contact has the highest success rate for convincing people.
# * According to job, the Management level people tend to say 'yes' for Opening Term Subscription followed by Technician and admin.
# * Total number of deposit count is no exceeds yes .
# * People who do not have housing and loan are more inclined towards saying yes for Deposit.
# * Highest level of acceptance and rejection of the deposit subscription is  in the month of May.

# %% [markdown]
# **14. CONCLUSION**

# %% [markdown]
# * In Data Visualization assignment 2 datasets are first searched, one each for Regression and Classification. The data in datasets is being checked for the co-relation between the existing attributes. Having complete information about the attributes helps in plotting the graph. Plotted graph gives a simple pictorial representation of the thousands of rows data that makes the data more meaningful.
# * Learned plotting of the different graphs , especially pie charts, relatable attributes that could be plotted on graph easily did not match the scaling sometimes,scaling them appropriately and finding out the sets of attribute that would a deliver the correct results was a task.

# %% [markdown]
# **15. REFERENCES**

# %% [markdown]
# 1. Goodfellow, I., Bengio, Y. and Courville, A. (2018). Deep learning.
# 2. GeeksforGeeks. (2019). Data visualization with different Charts in Python - GeeksforGeeks. [online] Available at: https://www.geeksforgeeks.org/data-visualization-different-charts-python/ [Accessed 10 Sep. 2019].
# 3. Matplotlib.org. (2019). Overview — Matplotlib 3.1.1 documentation. [online] Available at: https://matplotlib.org/3.1.1/contents.html [Accessed 10 Sep. 2019]
# 4. DataCamp Community. (2019). Python Seaborn Tutorial For Beginners. [online] Available at: https://www.datacamp.com/community/tutorials/seaborn-python-tutorial [Accessed 10 Sep. 2019].
# 5. Kaggle.com. (2019). International football results from 1872 to 2019. [online] Available at: https://www.kaggle.com/martj42/international-football-results-from-1872-to-2017 [Accessed 10 Sep. 2019].
# 6. Kaggle.com. (2019). Bank Marketing Dataset. [online] Available at: https://www.kaggle.com/janiobachmann/bank-marketing-dataset [Accessed 10 Sep. 2019].
